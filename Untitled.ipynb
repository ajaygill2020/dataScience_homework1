# %%
pip install -U pandas-profiling[notebook]
# Out:
# Requirement already satisfied: pandas-profiling[notebook] in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (1.4.1)
# Collecting pandas-profiling[notebook]
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.10.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (3.7.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.24.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (2.29.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (1.9.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (8.1.0)
# Requirement already satisfied: jupyter-core>=4.6.3 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (5.3.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas-profiling[notebook]) (8.0.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (2.8.4)
# Requirement already satisfied: imagehash in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (9.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (25.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jupyter-client>=5.3.4->pandas-profiling[notebook]) (6.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jupyter-core>=4.6.3->pandas-profiling[notebook]) (305.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling[notebook]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling[notebook]) (2022.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from pydantic>=1.8.1->pandas-profiling[notebook]) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from requests>=2.24.0->pandas-profiling[notebook]) (2023.5.7)
# Requirement already satisfied: colorama in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from tqdm>=4.48.2->pandas-profiling[notebook]) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (1.5.6)
# Requirement already satisfied: psutil in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.9.0)
# Requirement already satisfied: backcall in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->pandas-profiling[notebook]) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling[notebook]) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.5)
# Requirement already satisfied: executing in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ajayg\anaconda3\envs\aap\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->pandas-profiling[notebook]) (0.2.2)
# Installing collected packages: pandas-profiling
#   Attempting uninstall: pandas-profiling
#     Found existing installation: pandas-profiling 1.4.1
#     Uninstalling pandas-profiling-1.4.1:
#       Successfully uninstalled pandas-profiling-1.4.1
# Successfully installed pandas-profiling-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Ajay Gill
# MIS 6900 - Summer 2023
# 25 May 2023

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

housing_df = pd.read_csv("./data/kc_house_data_original.csv")

housing_df.info()

housing_df.head()


# Data prep steps
print(int(True), int(False))

housing_df['price_gt_1M'] = housing_df['price'].map(lambda x: int(x >= 1000000)) 

housing_df = housing_df.iloc[:, 2:]
housing_df.info()

newcols_class = [_ for _ in range(1, 20)]
newcols_class

newcols_regression = [_ for _ in range(1, 18)]
newcols_regression.extend([0])
newcols_regression

housing_class_df = housing_df.iloc[:, newcols_class]
housing_class_df.info()

housing_regression_df = housing_df.iloc[:, newcols_regression]
housing_regression_df.info()

housing_class_df.to_csv("./data/kc_house_data_classification.csv", index=False)
housing_regression_df.to_csv("./data/kc_house_data_regression.csv", index=False)


# EDA using pandas
# from pandas_profiling import ProfileReport
# profile = ProfileReport(train_df, title="Pandas Profiling Report")
# profile.to_file("output/pandas_profiling_report.html")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB
# 1 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
#  19  price_gt_1M    21613 non-null  int64
# dtypes: float64(5), int64(15)
# memory usage: 3.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       21613 non-null  int64
#  1   bathrooms      21613 non-null  float64
#  2   sqft_living    21613 non-null  int64
#  3   sqft_lot       21613 non-null  int64
#  4   floors         21613 non-null  float64
#  5   waterfront     21613 non-null  int64
#  6   view           21613 non-null  int64
#  7   condition      21613 non-null  int64
#  8   grade          21613 non-null  int64
#  9   sqft_above     21613 non-null  int64
#  10  sqft_basement  21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
#  17  sqft_lot15     21613 non-null  int64
#  18  price_gt_1M    21613 non-null  int64
# dtypes: float64(4), int64(15)
# memory usage: 3.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       21613 non-null  int64
#  1   bathrooms      21613 non-null  float64
#  2   sqft_living    21613 non-null  int64
#  3   sqft_lot       21613 non-null  int64
#  4   floors         21613 non-null  float64
#  5   waterfront     21613 non-null  int64
#  6   view           21613 non-null  int64
#  7   condition      21613 non-null  int64
#  8   grade          21613 non-null  int64
#  9   sqft_above     21613 non-null  int64
#  10  sqft_basement  21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
#  17  price          21613 non-null  float64
# dtypes: float64(5), int64(13)
# memory usage: 3.0 MB

# %%
from pandas_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from pandas_profiling import ProfileReport
#
# File ~\anaconda3\envs\aap\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 # -*- coding: utf-8 -*-
#       2 """Main module of pandas-profiling.
#       3
#       4 Docstring is compliant with NumPy/SciPy documentation standard:
#       5 https://github.com/numpy/numpy/blob/master/doc/HOWTO_DOCUMENT.rst.txt
# ----> 6 See also for a short description of docstring:
#       7 https://stackoverflow.com/questions/3898572/what-is-the-standard-python-docstring-format
#       8 """
#       9 import codecs
#      10 import pandas_profiling.templates as templates
#
# File ~\anaconda3\envs\aap\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       7 def profile_report(df: DataFrame, **kwargs) -> ProfileReport:
#       8     """Profile a DataFrame.
#       9
#      10     Args:
#    (...)
#      15         A ProfileReport of the DataFrame.
#      16     """
#
# File ~\anaconda3\envs\aap\Lib\site-packages\pandas_profiling\profile_report.py:15
#      13 from pandas_profiling.config import Config, Settings
#      14 from pandas_profiling.expectations_report import ExpectationsReport
# ---> 15 from pandas_profiling.model.alerts import AlertType
#      16 from pandas_profiling.model.describe import describe as describe_df
#      17 from pandas_profiling.model.sample import Sample
#
# File ~\anaconda3\envs\aap\Lib\site-packages\pandas_profiling\model\alerts.py:10
#       7 import pandas as pd
#       9 from pandas_profiling.config import Settings
# ---> 10 from pandas_profiling.model.correlations import perform_check_correlation
#      13 @unique
#      14 class AlertType(Enum):
#      15     """Alert types"""
#
# File ~\anaconda3\envs\aap\Lib\site-packages\pandas_profiling\model\correlations.py:8
#       6 import pandas as pd
#       7 from multimethod import multimethod
# ----> 8 from pandas.core.base import DataError
#      10 from pandas_profiling.config import Settings
#      13 class Correlation:
#
# ImportError: cannot import name 'DataError' from 'pandas.core.base' (C:\Users\ajayg\anaconda3\envs\aap\Lib\site-packages\pandas\core\base.py)

# %%
profile = ProfileReport(housing_df, title="Pandas Profiling Report")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 profile = ProfileReport(train_df, title="Pandas Profiling Report")
#
# NameError: name 'ProfileReport' is not defined

# %%
profile.to_file("output/pandas_profiling_report.html")
